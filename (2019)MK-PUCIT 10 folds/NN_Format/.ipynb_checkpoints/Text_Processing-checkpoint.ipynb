# %%
import nltk
#from nltk.corpus import brown
import re
import os
#from nltk import sent_tokenize, word_tokenize, pos_tag
import numpy as np
from array import *

import codecs
f = codecs.open("Single_file.txt", "r", "utf-8")
txt = f.readlines()
mylist = []
mysen = []
ltr = []
nplist = np.asarray(mylist,dtype=object)
x = 0
#txt = np.array(txt)
for i in txt:
    txt1 = i.split("\t", 1)
    #re.sub(r"[\n\t\s]*", "", txt)
    #print(txt1)
    if txt1 == ['\n']:
        x = x + 1
        #mysen.append(mylist)
        mylist.append(['*', 'Other'])
        #mylist = []
    else:
#         if len(txt1) > 0:
#             mylist.append(txt1[0] +' '+ txt1[1])
            
        mylist.append([re.sub(r"[\n\t\s]*", '', _) for _ in txt1])

print(len(mylist))
print(mylist[0][1])
print(x)

# length = len(mylist)
# i = 0
# p = 0
# while i < length:
#     if len(mylist[i]) < 2:
        
#         ltr.append(['L', 'SS'])
#         p += 1
#     else:
#         #print(mylist[i])
#         ltr.append(mylist[i][0]+', '+mylist[i][1]) #print(mylist[i][1], mylist[i][0])
#     i += 1
# q = 0 
# #j = 0
# temp_list = []
# for j in ltr:
#     if '*' in j:
#         mysen.append(temp_list)
#         temp_list = []
#         q += 1
#     else:
#         temp_list.append(j)
        
# print(ltr[0])    
        
# print(p)
# print(len(mylist))  
# print(len(ltr))  
# print(mysen[0])
# print(q)
    
# nplist = np.asarray(mylist,dtype=object)
# #print(re.sub(r"[\n\t\s]*", "", mylist[0][1]) +' '+ re.sub(r"[\n\t\s]*", "", mylist[0][0]))
# print(x)
# #print(nplist.shape)
# for i in mylist:
#     if ' ' == str([re.sub('[^a-zA-Z0-9]+', '', _) for _ in (re.sub(r"[\n\t\s]*", "", str(i)))]):
#         #x = x + 1
#         print('')
        
# print(mysen[1])
# print(x)

# with open(r'Output.txt', "w", encoding="utf8") as fp:
#     for item in mysen:
#         # write each item on a new line
#         fp.write("%s\n" % item)    

exit()
# Out:
# 962959
# Location
# 36216
